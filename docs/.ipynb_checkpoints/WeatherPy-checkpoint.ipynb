# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
temp = []
new_cities = []
wind = []

# %%
# URL for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#set counters
city_counter = 1
set_counter = 1

print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

#query data
for i, city in enumerate(cities):
    
    # Group cities as sets of 50s
    if (i % 50 == 0 and i >= 50):
        set_counter += 1
        city_counter = 1
         
    # Create API url for each city
    query_url = url +"&q=" + city
    
    # Get json respose for each city
    response = requests.get(query_url).json()
    
    # Print the results 
    print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
    
    # Increase city counter
    city_counter += 1
    
   # Add the values to the lists
    try:       
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        wind.append(response["wind"]["speed"])
        new_cities.append(response["name"])
    except:
        print("City not found. Skipping...")
        pass
    
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | halifax
# Processing Record 2 of Set 1 | tuatapere
# Processing Record 3 of Set 1 | port-cartier
# Processing Record 4 of Set 1 | tessalit
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | agva
# City not found. Skipping...
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | mayumba
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | sovetskaya gavan
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | abalak
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | selfoss
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | burica
# City not found. Skipping...
# Processing Record 22 of Set 1 | aykhal
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | portland
# Processing Record 26 of Set 1 | chiredzi
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | khorixas
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | fairbanks
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | hovd
# Processing Record 34 of Set 1 | lastoursville
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | los llanos de aridane
# Processing Record 39 of Set 1 | la rioja
# Processing Record 40 of Set 1 | marawi
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | huarmey
# Processing Record 43 of Set 1 | tiznit
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | faya
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | pedro ii
# Processing Record 5 of Set 2 | duluth
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 8 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | vreed en hoop
# City not found. Skipping...
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | jumla
# Processing Record 12 of Set 2 | sabalgarh
# Processing Record 13 of Set 2 | shevchenkove
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | umarizal
# Processing Record 17 of Set 2 | altay
# Processing Record 18 of Set 2 | pareora
# Processing Record 19 of Set 2 | camacha
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | namanga
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | batetskiy
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | korem
# Processing Record 28 of Set 2 | clonakilty
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | raymond terrace
# Processing Record 35 of Set 2 | port lavaca
# Processing Record 36 of Set 2 | maniitsoq
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | champerico
# Processing Record 40 of Set 2 | beringovskiy
# Processing Record 41 of Set 2 | whitecourt
# Processing Record 42 of Set 2 | maebaru
# Processing Record 43 of Set 2 | bosaso
# Processing Record 44 of Set 2 | rafaela
# Processing Record 45 of Set 2 | mantua
# Processing Record 46 of Set 2 | college
# Processing Record 47 of Set 2 | kamaishi
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | umm lajj
# Processing Record 3 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | inhambane
# Processing Record 6 of Set 3 | filingue
# Processing Record 7 of Set 3 | henties bay
# Processing Record 8 of Set 3 | coquimbo
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | comodoro rivadavia
# Processing Record 11 of Set 3 | tianpeng
# Processing Record 12 of Set 3 | conceicao do araguaia
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | lata
# Processing Record 18 of Set 3 | lebork
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | sokoni
# Processing Record 22 of Set 3 | zafra
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | riyadh
# Processing Record 25 of Set 3 | todos santos
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | salinopolis
# Processing Record 29 of Set 3 | okha
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | hasaki
# Processing Record 32 of Set 3 | acarau
# Processing Record 33 of Set 3 | dandong
# Processing Record 34 of Set 3 | tarko-sale
# Processing Record 35 of Set 3 | aloleng
# Processing Record 36 of Set 3 | tynda
# Processing Record 37 of Set 3 | isangel
# Processing Record 38 of Set 3 | el dorado
# Processing Record 39 of Set 3 | harper
# Processing Record 40 of Set 3 | celestun
# Processing Record 41 of Set 3 | binabalian
# Processing Record 42 of Set 3 | husavik
# Processing Record 43 of Set 3 | dangeni
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | narsaq
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | kyra
# Processing Record 48 of Set 3 | zabol
# Processing Record 49 of Set 3 | bethel
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | ahipara
# Processing Record 6 of Set 4 | ganzhou
# Processing Record 7 of Set 4 | zonguldak
# Processing Record 8 of Set 4 | ilulissat
# Processing Record 9 of Set 4 | bandar-e lengeh
# Processing Record 10 of Set 4 | aswan
# Processing Record 11 of Set 4 | san pedro
# Processing Record 12 of Set 4 | gouyave
# Processing Record 13 of Set 4 | anchorage
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | holiday
# Processing Record 16 of Set 4 | nanakuli
# Processing Record 17 of Set 4 | shubarkuduk
# Processing Record 18 of Set 4 | barisal
# Processing Record 19 of Set 4 | nyuksenitsa
# Processing Record 20 of Set 4 | noumea
# Processing Record 21 of Set 4 | torbay
# Processing Record 22 of Set 4 | yenagoa
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | sao lourenco do oeste
# Processing Record 25 of Set 4 | port lincoln
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | puerto el triunfo
# Processing Record 28 of Set 4 | irati
# Processing Record 29 of Set 4 | mari-turek
# Processing Record 30 of Set 4 | katherine
# Processing Record 31 of Set 4 | provideniya
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | korla
# Processing Record 35 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | lagoa
# Processing Record 38 of Set 4 | pangai
# Processing Record 39 of Set 4 | puerto leguizamo
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | prieska
# Processing Record 42 of Set 4 | manokwari
# Processing Record 43 of Set 4 | villarrobledo
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | vardo
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | la cruz
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | cherskiy
# Processing Record 50 of Set 4 | acopiara
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | tarpon springs
# Processing Record 3 of Set 5 | san cristobal
# Processing Record 4 of Set 5 | bara
# Processing Record 5 of Set 5 | santarem
# Processing Record 6 of Set 5 | constitucion
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | atar
# Processing Record 9 of Set 5 | la ronge
# Processing Record 10 of Set 5 | adrar
# Processing Record 11 of Set 5 | bandarbeyla
# Processing Record 12 of Set 5 | chapais
# Processing Record 13 of Set 5 | buraydah
# Processing Record 14 of Set 5 | roura
# Processing Record 15 of Set 5 | makasar
# Processing Record 16 of Set 5 | kholm
# Processing Record 17 of Set 5 | klaksvik
# Processing Record 18 of Set 5 | muros
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | sechura
# Processing Record 21 of Set 5 | necochea
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | sabha
# Processing Record 24 of Set 5 | rio gallegos
# Processing Record 25 of Set 5 | maturin
# Processing Record 26 of Set 5 | aksu
# Processing Record 27 of Set 5 | alice springs
# Processing Record 28 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 5 | de-kastri
# Processing Record 30 of Set 5 | olafsvik
# Processing Record 31 of Set 5 | svetlaya
# Processing Record 32 of Set 5 | lumut
# Processing Record 33 of Set 5 | touros
# Processing Record 34 of Set 5 | acapulco
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | putina
# Processing Record 37 of Set 5 | akhinos
# City not found. Skipping...
# Processing Record 38 of Set 5 | vao
# Processing Record 39 of Set 5 | selma
# Processing Record 40 of Set 5 | sangar
# Processing Record 41 of Set 5 | bako
# Processing Record 42 of Set 5 | gidole
# Processing Record 43 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 5 | harlingen
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | srednekolymsk
# Processing Record 47 of Set 5 | labuhan
# Processing Record 48 of Set 5 | yashkino
# Processing Record 49 of Set 5 | tual
# Processing Record 50 of Set 5 | hit
# Processing Record 1 of Set 6 | chapada dos guimaraes
# Processing Record 2 of Set 6 | pontevedra
# Processing Record 3 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 6 | nyaunglebin
# Processing Record 5 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 6 | huejuquilla el alto
# Processing Record 7 of Set 6 | deputatskiy
# Processing Record 8 of Set 6 | pemalang
# Processing Record 9 of Set 6 | bubaque
# Processing Record 10 of Set 6 | olinda
# Processing Record 11 of Set 6 | aklavik
# Processing Record 12 of Set 6 | plettenberg bay
# Processing Record 13 of Set 6 | reforma
# Processing Record 14 of Set 6 | tateyama
# Processing Record 15 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 6 | zyryanka
# Processing Record 17 of Set 6 | pionerskiy
# Processing Record 18 of Set 6 | sheridan
# Processing Record 19 of Set 6 | wloszczowa
# Processing Record 20 of Set 6 | lohardaga
# Processing Record 21 of Set 6 | cefalu
# Processing Record 22 of Set 6 | seymchan
# Processing Record 23 of Set 6 | cabatuan
# Processing Record 24 of Set 6 | abay
# Processing Record 25 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 6 | cabo rojo
# Processing Record 27 of Set 6 | terney
# Processing Record 28 of Set 6 | caravelas
# Processing Record 29 of Set 6 | salalah
# Processing Record 30 of Set 6 | zbiroh
# Processing Record 31 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 6 | longyearbyen
# Processing Record 33 of Set 6 | malindi
# Processing Record 34 of Set 6 | havelock
# Processing Record 35 of Set 6 | pontal do parana
# Processing Record 36 of Set 6 | monticello
# Processing Record 37 of Set 6 | hamilton
# Processing Record 38 of Set 6 | brenes
# Processing Record 39 of Set 6 | biloela
# Processing Record 40 of Set 6 | monrovia
# Processing Record 41 of Set 6 | log
# Processing Record 42 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 6 | viedma
# Processing Record 44 of Set 6 | antofagasta
# Processing Record 45 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 6 | ixtapa
# Processing Record 47 of Set 6 | flinders
# Processing Record 48 of Set 6 | biak
# Processing Record 49 of Set 6 | payyannur
# Processing Record 50 of Set 6 | kieta
# Processing Record 1 of Set 7 | margate
# Processing Record 2 of Set 7 | namatanai
# Processing Record 3 of Set 7 | sibolga
# Processing Record 4 of Set 7 | mount gambier
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | lebu
# Processing Record 7 of Set 7 | sorland
# Processing Record 8 of Set 7 | cavarzere
# Processing Record 9 of Set 7 | progreso
# Processing Record 10 of Set 7 | yichun
# Processing Record 11 of Set 7 | tukrah
# Processing Record 12 of Set 7 | novo aripuana
# Processing Record 13 of Set 7 | iquitos
# Processing Record 14 of Set 7 | saran
# Processing Record 15 of Set 7 | zary
# Processing Record 16 of Set 7 | lempaala
# Processing Record 17 of Set 7 | belyy yar
# Processing Record 18 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 7 | dzaoudzi
# Processing Record 20 of Set 7 | xiaoweizhai
# Processing Record 21 of Set 7 | road town
# Processing Record 22 of Set 7 | haines junction
# Processing Record 23 of Set 7 | denpasar
# Processing Record 24 of Set 7 | angra
# City not found. Skipping...
# Processing Record 25 of Set 7 | ancud
# Processing Record 26 of Set 7 | cabo san lucas
# Processing Record 27 of Set 7 | aldergrove
# Processing Record 28 of Set 7 | lufilufi
# Processing Record 29 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 30 of Set 7 | merauke
# Processing Record 31 of Set 7 | maldonado
# Processing Record 32 of Set 7 | gat
# Processing Record 33 of Set 7 | batagay-alyta
# Processing Record 34 of Set 7 | katra
# Processing Record 35 of Set 7 | usinsk
# Processing Record 36 of Set 7 | bilibino
# Processing Record 37 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 7 | saint-francois
# Processing Record 39 of Set 7 | oban
# Processing Record 40 of Set 7 | lesosibirsk
# Processing Record 41 of Set 7 | izumo
# Processing Record 42 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 7 | lompoc
# Processing Record 44 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 7 | barsi
# Processing Record 46 of Set 7 | havoysund
# Processing Record 47 of Set 7 | yinchuan
# Processing Record 48 of Set 7 | ankola
# Processing Record 49 of Set 7 | bay roberts
# Processing Record 50 of Set 7 | thompson
# Processing Record 1 of Set 8 | lashio
# Processing Record 2 of Set 8 | cobija
# Processing Record 3 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 8 | gweta
# Processing Record 6 of Set 8 | udachnyy
# Processing Record 7 of Set 8 | tommot
# Processing Record 8 of Set 8 | remedios
# Processing Record 9 of Set 8 | urumqi
# Processing Record 10 of Set 8 | tilichiki
# Processing Record 11 of Set 8 | aleksandrovka
# Processing Record 12 of Set 8 | falun
# Processing Record 13 of Set 8 | zheleznodorozhnyy
# Processing Record 14 of Set 8 | gambela
# Processing Record 15 of Set 8 | tautira
# Processing Record 16 of Set 8 | vanimo
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | pisco
# Processing Record 19 of Set 8 | marin
# Processing Record 20 of Set 8 | ribeira grande
# Processing Record 21 of Set 8 | xam nua
# Processing Record 22 of Set 8 | safranbolu
# Processing Record 23 of Set 8 | anjiang
# Processing Record 24 of Set 8 | ponta delgada
# Processing Record 25 of Set 8 | jacksonville
# Processing Record 26 of Set 8 | kavieng
# Processing Record 27 of Set 8 | severo-kurilsk
# Processing Record 28 of Set 8 | praia da vitoria
# Processing Record 29 of Set 8 | valer
# Processing Record 30 of Set 8 | panama city
# Processing Record 31 of Set 8 | lubango
# Processing Record 32 of Set 8 | hobyo
# Processing Record 33 of Set 8 | plouzane
# Processing Record 34 of Set 8 | rio grande
# Processing Record 35 of Set 8 | swellendam
# Processing Record 36 of Set 8 | dikson
# Processing Record 37 of Set 8 | saint anthony
# Processing Record 38 of Set 8 | kathmandu
# Processing Record 39 of Set 8 | nago
# Processing Record 40 of Set 8 | camacupa
# Processing Record 41 of Set 8 | benguela
# Processing Record 42 of Set 8 | aripuana
# Processing Record 43 of Set 8 | tingi
# Processing Record 44 of Set 8 | auki
# Processing Record 45 of Set 8 | dolovo
# Processing Record 46 of Set 8 | puerto escondido
# Processing Record 47 of Set 8 | ormara
# Processing Record 48 of Set 8 | uusikaupunki
# Processing Record 49 of Set 8 | tiarei
# Processing Record 50 of Set 8 | mindelo
# Processing Record 1 of Set 9 | waingapu
# Processing Record 2 of Set 9 | manggar
# Processing Record 3 of Set 9 | albury
# Processing Record 4 of Set 9 | hami
# Processing Record 5 of Set 9 | feijo
# Processing Record 6 of Set 9 | novikovo
# Processing Record 7 of Set 9 | hambantota
# Processing Record 8 of Set 9 | camargo
# Processing Record 9 of Set 9 | kattivakkam
# Processing Record 10 of Set 9 | virginia beach
# Processing Record 11 of Set 9 | vitre
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | markivka
# Processing Record 14 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 9 | agirish
# Processing Record 16 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 17 of Set 9 | kirando
# Processing Record 18 of Set 9 | smolenka
# Processing Record 19 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 9 | codrington
# Processing Record 21 of Set 9 | arona
# Processing Record 22 of Set 9 | labuan
# Processing Record 23 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 24 of Set 9 | roros
# Processing Record 25 of Set 9 | shimoda
# Processing Record 26 of Set 9 | banikoara
# Processing Record 27 of Set 9 | urucara
# Processing Record 28 of Set 9 | oranjestad
# Processing Record 29 of Set 9 | kununurra
# Processing Record 30 of Set 9 | chunoyar
# Processing Record 31 of Set 9 | konevo
# Processing Record 32 of Set 9 | gulfport
# Processing Record 33 of Set 9 | nome
# Processing Record 34 of Set 9 | karpogory
# Processing Record 35 of Set 9 | half moon bay
# Processing Record 36 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 9 | mount isa
# Processing Record 38 of Set 9 | almaznyy
# Processing Record 39 of Set 9 | xai-xai
# Processing Record 40 of Set 9 | tam ky
# Processing Record 41 of Set 9 | pauini
# Processing Record 42 of Set 9 | ust-maya
# Processing Record 43 of Set 9 | kazerun
# Processing Record 44 of Set 9 | dobris
# Processing Record 45 of Set 9 | maragogi
# Processing Record 46 of Set 9 | kahului
# Processing Record 47 of Set 9 | budhlada
# Processing Record 48 of Set 9 | casay
# Processing Record 49 of Set 9 | hegang
# Processing Record 50 of Set 9 | tatarsk
# Processing Record 1 of Set 10 | lakes entrance
# Processing Record 2 of Set 10 | xuddur
# Processing Record 3 of Set 10 | yangambi
# Processing Record 4 of Set 10 | evensk
# Processing Record 5 of Set 10 | ishikari
# Processing Record 6 of Set 10 | port macquarie
# Processing Record 7 of Set 10 | agucadoura
# Processing Record 8 of Set 10 | leninsk
# Processing Record 9 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 10 of Set 10 | san carlos de bariloche
# Processing Record 11 of Set 10 | san quintin
# Processing Record 12 of Set 10 | darhan
# Processing Record 13 of Set 10 | bitkine
# Processing Record 14 of Set 10 | statesville
# Processing Record 15 of Set 10 | jiwani
# Processing Record 16 of Set 10 | kaeo
# Processing Record 17 of Set 10 | cheyenne
# Processing Record 18 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 10 | sydney
# Processing Record 20 of Set 10 | shitanjing
# Processing Record 21 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 23 of Set 10 | sabzevar
# Processing Record 24 of Set 10 | ucluelet
# Processing Record 25 of Set 10 | rocha
# Processing Record 26 of Set 10 | pimentel
# Processing Record 27 of Set 10 | poum
# Processing Record 28 of Set 10 | hokitika
# Processing Record 29 of Set 10 | sao felix do xingu
# Processing Record 30 of Set 10 | namibe
# Processing Record 31 of Set 10 | ziro
# Processing Record 32 of Set 10 | paragominas
# Processing Record 33 of Set 10 | vokhtoga
# Processing Record 34 of Set 10 | calatagan
# Processing Record 35 of Set 10 | yumen
# Processing Record 36 of Set 10 | ewo
# Processing Record 37 of Set 10 | danjiangkou
# Processing Record 38 of Set 10 | snyder
# Processing Record 39 of Set 10 | miri
# Processing Record 40 of Set 10 | olga
# Processing Record 41 of Set 10 | camopi
# Processing Record 42 of Set 10 | grand-lahou
# Processing Record 43 of Set 10 | saint george
# Processing Record 44 of Set 10 | abu kamal
# Processing Record 45 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 46 of Set 10 | powell
# Processing Record 47 of Set 10 | vila franca do campo
# Processing Record 48 of Set 10 | mujiayingzi
# Processing Record 49 of Set 10 | mayskiy
# Processing Record 50 of Set 10 | bagotville
# Processing Record 1 of Set 11 | berlevag
# Processing Record 2 of Set 11 | wakkanai
# Processing Record 3 of Set 11 | ambilobe
# Processing Record 4 of Set 11 | moengo
# Processing Record 5 of Set 11 | arrigorriaga
# Processing Record 6 of Set 11 | sayyan
# Processing Record 7 of Set 11 | great falls
# Processing Record 8 of Set 11 | jilin
# Processing Record 9 of Set 11 | akyab
# Processing Record 10 of Set 11 | komsomolskiy
# Processing Record 11 of Set 11 | majholi
# Processing Record 12 of Set 11 | geraldton
# Processing Record 13 of Set 11 | hudson bay
# Processing Record 14 of Set 11 | saharanpur
# Processing Record 15 of Set 11 | sola
# Processing Record 16 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 11 | malangali
# Processing Record 18 of Set 11 | kendari
# Processing Record 19 of Set 11 | tomatlan
# Processing Record 20 of Set 11 | micheweni
# Processing Record 21 of Set 11 | dubai
# Processing Record 22 of Set 11 | sanchursk
# Processing Record 23 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 24 of Set 11 | itoman
# Processing Record 25 of Set 11 | pochutla
# Processing Record 26 of Set 11 | palana
# Processing Record 27 of Set 11 | itaqui
# Processing Record 28 of Set 11 | formiga
# Processing Record 29 of Set 11 | kollam
# Processing Record 30 of Set 11 | norman wells
# Processing Record 31 of Set 11 | gedo
# Processing Record 32 of Set 11 | barcelos
# Processing Record 33 of Set 11 | mangan
# Processing Record 34 of Set 11 | canico
# Processing Record 35 of Set 11 | anadyr
# Processing Record 36 of Set 11 | el paso
# Processing Record 37 of Set 11 | naze
# Processing Record 38 of Set 11 | beyneu
# Processing Record 39 of Set 11 | seropedica
# Processing Record 40 of Set 11 | leopold
# Processing Record 41 of Set 11 | rawson
# Processing Record 42 of Set 11 | svirsk
# Processing Record 43 of Set 11 | banda aceh
# Processing Record 44 of Set 11 | george town
# Processing Record 45 of Set 11 | dombarovskiy
# Processing Record 46 of Set 11 | bereda
# Processing Record 47 of Set 11 | angren
# Processing Record 48 of Set 11 | bac lieu
# Processing Record 49 of Set 11 | bhadrachalam
# Processing Record 50 of Set 11 | dourbali
# Processing Record 1 of Set 12 | zverinogolovskoye
# Processing Record 2 of Set 12 | bathsheba
# Processing Record 3 of Set 12 | shakawe
# Processing Record 4 of Set 12 | suining
# Processing Record 5 of Set 12 | roald
# Processing Record 6 of Set 12 | kudahuvadhoo
# Processing Record 7 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 8 of Set 12 | topolobampo
# Processing Record 9 of Set 12 | ishigaki
# Processing Record 10 of Set 12 | sovetskiy
# Processing Record 11 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 12 | gawler
# Processing Record 13 of Set 12 | taunggyi
# Processing Record 14 of Set 12 | port hedland
# Processing Record 15 of Set 12 | katobu
# Processing Record 16 of Set 12 | koygorodok
# Processing Record 17 of Set 12 | kyabe
# Processing Record 18 of Set 12 | praia
# Processing Record 19 of Set 12 | zharkent
# Processing Record 20 of Set 12 | kaitangata
# Processing Record 21 of Set 12 | khorinsk
# Processing Record 22 of Set 12 | buala
# Processing Record 23 of Set 12 | goderich
# Processing Record 24 of Set 12 | rovaniemi
# Processing Record 25 of Set 12 | suoyarvi
# Processing Record 26 of Set 12 | nelson bay
# Processing Record 27 of Set 12 | marshalltown
# Processing Record 28 of Set 12 | hay river
# Processing Record 29 of Set 12 | bernay
# Processing Record 30 of Set 12 | sirsa
# Processing Record 31 of Set 12 | kulunda
# Processing Record 32 of Set 12 | lahaina
# Processing Record 33 of Set 12 | mabaruma
# Processing Record 34 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 12 | wakiso
# Processing Record 36 of Set 12 | porto san giorgio
# Processing Record 37 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 12 | mwinilunga
# Processing Record 39 of Set 12 | pangody
# Processing Record 40 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 41 of Set 12 | charters towers
# Processing Record 42 of Set 12 | konigs wusterhausen
# Processing Record 43 of Set 12 | maumere
# Processing Record 44 of Set 12 | souillac
# Processing Record 45 of Set 12 | arman
# Processing Record 46 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 47 of Set 12 | axim
# Processing Record 48 of Set 12 | yerbogachen
# Processing Record 49 of Set 12 | morondava
# Processing Record 50 of Set 12 | mokhotlong
# Processing Record 1 of Set 13 | srivardhan
# Processing Record 2 of Set 13 | kenai
# Processing Record 3 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 13 | dudinka
# Processing Record 5 of Set 13 | kuruman
# Processing Record 6 of Set 13 | xinmin
# Processing Record 7 of Set 13 | coari
# Processing Record 8 of Set 13 | aosta
# Processing Record 9 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 10 of Set 13 | krasnoselkup
# Processing Record 11 of Set 13 | asau
# Processing Record 12 of Set 13 | tecoanapa
# Processing Record 13 of Set 13 | verkhnevilyuysk
# Processing Record 14 of Set 13 | sakakah
# Processing Record 15 of Set 13 | san angelo
# Processing Record 16 of Set 13 | luoyang
# Processing Record 17 of Set 13 | assiniboia
# Processing Record 18 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 13 | kuah
# Processing Record 20 of Set 13 | dera bugti
# Processing Record 21 of Set 13 | khandyga
# Processing Record 22 of Set 13 | pingliang
# Processing Record 23 of Set 13 | kenora
# Processing Record 24 of Set 13 | kimbe
# Processing Record 25 of Set 13 | quatre cocos
# Processing Record 26 of Set 13 | ranong
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Max Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
#create dataframe
weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City          568
# Cloudiness    568
# Country       568
# Date          568
# Humidity      568
# Max Temp      568
# Lat           568
# Lng           568
# Wind Speed    568
# dtype: int64

# %%
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Max Temp    Lat  \
# 0       Halifax         100      CA  1588379290        82     51.01  44.65
# 1     Tuatapere         100      NZ  1588379421        85     54.14 -46.13
# 2  Port-Cartier          90      CA  1588379421       100     39.99  50.03
# 3      Tessalit           0      ML  1588379421        13     85.14  20.20
# 4  Punta Arenas          75      CL  1588379421        81     48.20 -53.15
#
#       Lng  Wind Speed
# 0  -63.57        4.00
# 1  167.68        3.98
# 2  -66.87       10.29
# 3    1.01       12.73
# 4  -70.92       16.11

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker = "o", facecolor = "navy", edgecolor="black")
plt.title("City Latitude vs. Max Temp" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid()
plt.savefig("output_data/temp.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-4b0eb403303d> in <module>
#       1 plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker = "o", facecolor = "navy", edgecolor="black")
# ----> 2 plt.title("City Latitude vs. Max Temp" % time.strftime("%x"))
#       3 plt.xlabel("Latitude")
#       4 plt.ylabel("Max Temp (F)")
#       5 plt.grid()
#
# TypeError: not all arguments converted during string formatting

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker = "o", facecolor = "navy", edgecolor="black")
plt.title("Latitude vs. Humidity" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.savefig("output_data/humidity.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-ace91bf0c2ca> in <module>
#       1 plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker = "o", facecolor = "navy", edgecolor="black")
# ----> 2 plt.title("Latitude vs. Humidity" % time.strftime("%x"))
#       3 plt.xlabel("Latitude")
#       4 plt.ylabel("Humidity")
#       5 plt.grid()
#
# TypeError: not all arguments converted during string formatting

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker = "o", facecolor = "navy", edgecolor="black")
plt.title("Latitude vs. Cloudiness" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.savefig("output_data/cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker = "o", facecolor = "navy", edgecolor="black")
plt.title("Latitude vs. Wind Speed" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.savefig("output_data/wind_speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
